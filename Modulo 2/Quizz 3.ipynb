# %%
import numpy as np

# %%
u1 = 0.23 - 0.5*3*0.1**2
u2 = 0.30 - 0.5*3*0.15**2
u3 = 0.26 - 0.5*3*0.4**2

u1, u2, u3
# Out:
# (0.215, 0.26625, 0.019999999999999962)

# %%
np.round(u2, 3)
# Out:
# 0.266

# %%
u1 = 0.22 - 0.5*2*0.3**2
u2 = 0.05 - 0.5*2*0**2

u1, u2
# Out:
# (0.13, 0.05)

# %%
np.round(u1, 3)
# Out:
# 0.13

# %%
rs = (0.22 - 0.05)/ 0.3

np.round(rs, 3)
# Out:
# 0.567

# %%
r1 = 0.15
vol1 = 0.2
r2 = 0.05
vol2 = 0
w1 = 0.5
w2 = 0.5

rpor = w1*r1 + w2*r2

np.round(rpor, 3)
# Out:
# 0.1

# %%
volpor = w1**2 * vol1**2 + w2**2 * vol2**2 + 2
